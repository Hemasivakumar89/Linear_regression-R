# %%
library(ggplot2)
library(dplyr)

# %%
readfile <- read.csv("regrex1.csv")

# %%
ggplot(readfile, aes(x=x, y=y, color="red")) + geom_point()
# Out:
# plot without title

# %%
model = lm(x ~ y, readfile)

# %%
plot(readfile, col="red")
abline(model, col="blue", lwd=3)
# Out:
# plot without title
